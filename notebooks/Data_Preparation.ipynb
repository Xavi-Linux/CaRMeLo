# %% [markdown]
# ## Import Libraries

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap, ListedColormap
from pandas.io.formats.style import Styler
from pathlib import Path
from typing import Any, Callable, Dict, List, TypeVar

# %%
pd.set_option('display.max_rows', None, 'display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
# !pwd
# Out:
# /home/xavi/Documents/CreditRisk/notebooks

# %%
file: Path = Path('/home/xavi/Documents/CreditRisk/data/curated/dataset.parquet')

# %%
df: pd.DataFrame = pd.read_parquet(file, engine='pyarrow')

# %% [markdown]
# ### Depedent variable:

# %%
df['loan_status'].value_counts(dropna=False, normalize=True)
# Out:
# loan_status
# Current                                                0.480878
# Fully Paid                                             0.396193
# Charged Off                                            0.091092
# Late (31-120 days)                                     0.014798
# In Grace Period                                        0.006747
# Does not meet the credit policy. Status:Fully Paid     0.004263
# Late (16-30 days)                                      0.002612
# Default                                                0.001784
# Does not meet the credit policy. Status:Charged Off    0.001632
# Name: proportion, dtype: float64

# %%
defaults: List[str] = [
    'Charged Off',
    'Late (31-120 days)',
    'Default',
    'Does not meet the credit policy. Status:Charged Off'
]

# %%
is_in_defaults: Callable  = defaults.__contains__

# %%
df['non_default'] = df['loan_status'].apply(lambda v: 0 if is_in_defaults(v) else 1)

# %%
df['non_default'].value_counts(dropna=False, normalize=True).apply('{0:.2%}'.format)
# Out:
# non_default
# 1    89.07%
# 0    10.93%
# Name: proportion, dtype: object

# %% [markdown]
# ### Train-test split

# %%
SEED = 19

# %%
PROPORTION = .9

# %%
is_in_train_set = df['non_default'].reset_index()\
                                   .groupby('non_default', group_keys=False)\
                                   .apply(lambda s: s.sample(frac=PROPORTION, random_state=SEED))['id'].values

# %%
df['is_in_train'] = df.index.isin(is_in_train_set)

# %%
df['is_in_train'].value_counts()/len(df)
# Out:
# is_in_train
# True     0.899999
# False    0.100001
# Name: count, dtype: float64

# %%
df_train = df[df['is_in_train']].copy()

# %%
df_train.shape
# Out:
# (419656, 79)

# %%
df_train['non_default'].value_counts(dropna=False, normalize=True)
# Out:
# non_default
# 1    0.890694
# 0    0.109306
# Name: proportion, dtype: float64

# %% [markdown]
# ### Indepent variables

# %% [markdown]
# #### Discrete variables

# %%
category_mask: pd.Series = df_train.dtypes == 'category'

# %%
categories: List[str] = df_train.dtypes[category_mask].index.to_list()

# %%
cat_df: pd.DataFrame = df_train[categories + ['non_default']].drop('issue_d', axis=1)

# %%
categories.remove('issue_d')
categories.remove('loan_status')

# %%
categories
# Out:
# ['term',
#  'grade',
#  'sub_grade',
#  'emp_length',
#  'home_ownership',
#  'verification_status',
#  'pymnt_plan',
#  'purpose',
#  'addr_state',
#  'initial_list_status',
#  'policy_code',
#  'application_type']

# %% [markdown]
# **WoE and IV calculation**:

# %%
def calculate_woe_iv(data:pd.DataFrame, variable:pd.Series, target:pd.Series, multilevel_index:bool = False, sort_by_woe: bool = True, aggfunc: Callable = len) -> pd.DataFrame:
    pivot = pd.pivot_table(data=data, index=variable, columns=target, aggfunc=aggfunc, fill_value=0, values=[])
    pivot['n_obs'] = pivot.apply(axis=1, func=np.sum)
    pivot['n_obs_rel'] = pivot['n_obs'] / pivot['n_obs'].sum()

    #add .00000005 to handle errors when calculating WoE (ln(0))
    pivot['bad_rel'] = (pivot[0] + .00000005) / pivot[0].sum()
    pivot['good_rel'] = (pivot[1] + .00000005) / pivot[1].sum()

    pivot['woe'] = np.log(pivot['good_rel']) - np.log(pivot['bad_rel'])

    if sort_by_woe:
        pivot = pivot.sort_values(by='woe', ascending=True)

    else:
        pivot = pivot.sort_index(ascending=True)
        
    pivot['good_rel_diff'] = pivot['good_rel'].diff().abs()
    pivot['bad_rel_diff'] = pivot['bad_rel'].diff().abs()
    pivot['woe_diff'] = pivot['woe'].diff().abs()
    pivot['accum_n_obs_rel'] = pivot['n_obs_rel'].cumsum()
    
    pivot['iv'] = ((pivot['good_rel'] - pivot['bad_rel']) * pivot['woe']).sum()
    
    if multilevel_index:
        pivot['variable'] = variable.name
        pivot = pivot.set_index(['variable', pivot.index])

    if sort_by_woe:
        return pivot.sort_values(by='woe', ascending=True)

    return pivot.sort_index(ascending=True)

# %%
def run_woe_iv(data:pd.DataFrame, independent_vars:List[str], dependent_var:str) -> pd.DataFrame:
    accum: pd.Dataframe = pd.DataFrame([])
    for v in independent_vars:
        result = calculate_woe_iv(data[[v, dependent_var]], data[v], data[dependent_var], multilevel_index=True)
        accum = pd.concat([accum, result], axis=0)

    return accum

# %%
calculate_woe_iv(cat_df, cat_df['grade'], cat_df['non_default'], multilevel_index=True)
# Out:
# non_default         0       1   n_obs  n_obs_rel   bad_rel  good_rel  \
# variable grade
# grade    G        843    2158    3001   0.007151  0.018378  0.005773
#          F       2886    9089   11975   0.028535  0.062916  0.024316
#          E       6292   25971   32263   0.076880  0.137167  0.069481
#          D      10647   58492   69139   0.164752  0.232107  0.156486
#          C      12944   99728  112672   0.268487  0.282183  0.266806
#          B       9683  113551  123234   0.293655  0.211092  0.303787
#          A       2576   64796   67372   0.160541  0.056157  0.173351
#
# non_default          woe  good_rel_diff  bad_rel_diff  woe_diff  \
# variable grade
# grade    G     -1.157877            NaN           NaN       NaN
#          F     -0.950654       0.018543      0.044538  0.207223
#          E     -0.680146       0.045165      0.074252  0.270508
#          D     -0.394236       0.087005      0.094940  0.285910
#          C     -0.056034       0.110320      0.050075  0.338202
#          B      0.364033       0.036981      0.071091  0.420066
#          A      1.127158       0.130436      0.154934  0.763126
#
# non_default     accum_n_obs_rel        iv
# variable grade
# grade    G             0.007151  0.293839
#          F             0.035686  0.293839
#          E             0.112566  0.293839
#          D             0.277318  0.293839
#          C             0.545804  0.293839
#          B             0.839459  0.293839
#          A             1.000000  0.293839

# %% [markdown]
# **Style Woe calculations**

# %%
def style_woe_frame(d: pd.DataFrame) -> Styler:
    index_style = """background-color: #b20f4f;
                     border-width: 2px;
                     border-color: #ffffff;
                     border-style: solid;
                     text-align: center;
                  """
    below_five_pct_style = """
                     background-color: #cc5040;
                     border-width: 1px;
                     border-color: #ffffff;
                     border-style: dashed;
                  """

    colours: List[str] = ['#f0a324', '#f0d424', '#c4daaa', '#aad140', '#91f024', '#ef6852']
    nodes: List[float] = [0, .02, .1, .3, .5, 1]
    cmap = LinearSegmentedColormap.from_list('iv_map', list(zip(nodes, colours)))
    
    return d.style.format(thousands=',', precision=3)\
            .apply_index(lambda s: pd.Series(index_style, index=s.index), axis=0)\
            .apply_index(lambda s: pd.Series(index_style, index=s.index), axis=1)\
            .bar(color=('#de9910', '#7acd53'), align='zero', subset=['woe'], width=80, height=80)\
            .format('{0:.2%}', subset=['n_obs_rel', 'bad_rel', 'good_rel', 'accum_n_obs_rel'])\
            .set_caption('Weight of evidence analysis')\
            .highlight_between(subset=['n_obs_rel'], props=below_five_pct_style, left=0, right=.05, inclusive='right')\
            .background_gradient(cmap=cmap, vmin=0, vmax=1, subset=['iv'])

# %%
style_woe_frame(calculate_woe_iv(cat_df, cat_df['grade'], cat_df['non_default'], multilevel_index=True))
# Out:
# <style type="text/css">
# #T_32c22_row0_col3, #T_32c22_row1_col3 {
#   background-color: #cc5040;
#   border-width: 1px;
#   border-color: #ffffff;
#   border-style: dashed;
# }
# #T_32c22_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_32c22_row0_col11, #T_32c22_row1_col11, #T_32c22_row2_col11, #T_32c22_row3_col11, #T_32c22_row4_col11, #T_32c22_row5_col11, #T_32c22_row6_col11 {
#   background-color: #abd143;
#   color: #000000;
# }
# #T_32c22_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 7.2%, #de9910 7.2%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_32c22_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.5%, #de9910 16.5%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_32c22_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.4%, #de9910 26.4%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_32c22_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.1%, #de9910 38.1%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_32c22_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 52.6%, transparent 52.6%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_32c22_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 78.9%, transparent 78.9%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_32c22_level0_row0, #T_32c22_level1_row0, #T_32c22_level1_row1, #T_32c22_level1_row2, #T_32c22_level1_row3, #T_32c22_level1_row4, #T_32c22_level1_row5, #T_32c22_level1_row6 {
#   background-color: #b20f4f;
#   border-width: 2px;
#   border-color: #ffffff;
#   border-style: solid;
#   text-align: center;
# }
# #T_32c22_level0_col0, #T_32c22_level0_col1, #T_32c22_level0_col2, #T_32c22_level0_col3, #T_32c22_level0_col4, #T_32c22_level0_col5, #T_32c22_level0_col6, #T_32c22_level0_col7, #T_32c22_level0_col8, #T_32c22_level0_col9, #T_32c22_level0_col10, #T_32c22_level0_col11 {
#   background-color: #b20f4f;
#   border-width: 2px;
#   border-color: #ffffff;
#   border-style: solid;
#   text-align: center;
# }
# </style>
# <table id="T_32c22">
#   <caption>Weight of evidence analysis</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >non_default</th>
#       <th id="T_32c22_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_32c22_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_32c22_level0_col2" class="col_heading level0 col2" >n_obs</th>
#       <th id="T_32c22_level0_col3" class="col_heading level0 col3" >n_obs_rel</th>
#       <th id="T_32c22_level0_col4" class="col_heading level0 col4" >bad_rel</th>
#       <th id="T_32c22_level0_col5" class="col_heading level0 col5" >good_rel</th>
#       <th id="T_32c22_level0_col6" class="col_heading level0 col6" >woe</th>
#       <th id="T_32c22_level0_col7" class="col_heading level0 col7" >good_rel_diff</th>
#       <th id="T_32c22_level0_col8" class="col_heading level0 col8" >bad_rel_diff</th>
#       <th id="T_32c22_level0_col9" class="col_heading level0 col9" >woe_diff</th>
#       <th id="T_32c22_level0_col10" class="col_heading level0 col10" >accum_n_obs_rel</th>
#       <th id="T_32c22_level0_col11" class="col_heading level0 col11" >iv</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th class="index_name level1" >grade</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
>0.294</td>
#     </tr>
#     <tr>
#       <th id="T_32c22_level1_row4" class="row_heading leve

# %%
woe_summary = run_woe_iv(data=cat_df, independent_vars=categories, dependent_var='non_default')

# %%
woe_summary.groupby(level=0)['iv'].max().sort_values(ascending=False).apply(lambda v: '{0}'.format(str(v)))
# Out:
# variable
# sub_grade                 0.31801257871646604
# grade                     0.29383944484595614
# term                      0.03964422510341349
# purpose                   0.03678649744024622
# initial_list_status      0.024876385244176548
# home_ownership            0.02134309680189488
# verification_status       0.02044927654461296
# addr_state               0.012440268872908673
# emp_length               0.005116449325983384
# pymnt_plan             0.00013840433948306575
# application_type        9.145978886378884e-25
# policy_code             9.145978886378884e-25
# Name: iv, dtype: object

# %%
style_woe_frame(woe_summary)
# Out:
# <style type="text/css">
# #T_1603f_row0_col6, #T_1603f_row28_col6, #T_1603f_row70_col6, #T_1603f_row71_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.3%, #de9910 39.3%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_1603f_row0_col11, #T_1603f_row1_col11 {
#   background-color: #e5d544;
#   color: #000000;
# }
# #T_1603f_row1_col6, #T_1603f_row76_col6, #T_1603f_row113_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 40.3%, transparent 40.3%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_1603f_row2_col3, #T_1603f_row3_col3, #T_1603f_row9_col3, #T_1603f_row10_col3, #T_1603f_row11_col3, #T_1603f_row12_col3, #T_1603f_row13_col3, #T_1603f_row14_col3, #T_1603f_row15_col3, #T_1603f_row16_col3, #T_1603f_row17_col3, #T_1603f_row18_col3, #T_1603f_row19_col3, #T_1603f_row20_col3, #T_1603f_row21_col3, #T_1603f_row22_col3, #T_1603f_row23_col3, #T_1603f_row24_col3, #T_1603f_row25_col3, #T_1603f_row26_col3, #T_1603f_row27_col3, #T_1603f_row28_col3, #T_1603f_row29_col3, #T_1603f_row38_col3, #T_1603f_row39_col3, #T_1603f_row40_col3, #T_1603f_row41_col3, #T_1603f_row42_col3, #T_1603f_row43_col3, #T_1603f_row49_col3, #T_1603f_row55_col3, #T_1603f_row56_col3, #T_1603f_row60_col3, #T_1603f_row64_col3, #T_1603f_row66_col3, #T_1603f_row67_col3, #T_1603f_row68_col3, #T_1603f_row69_col3, #T_1603f_row70_col3, #T_1603f_row72_col3, #T_1603f_row73_col3, #T_1603f_row74_col3, #T_1603f_row77_col3, #T_1603f_row78_col3, #T_1603f_row80_col3, #T_1603f_row81_col3, #T_1603f_row82_col3, #T_1603f_row83_col3, #T_1603f_row85_col3, #T_1603f_row86_col3, #T_1603f_row88_col3, #T_1603f_row89_col3, #T_1603f_row90_col3, #T_1603f_row91_col3, #T_1603f_row92_col3, #T_1603f_row93_col3, #T_1603f_row94_col3, #T_1603f_row96_col3, #T_1603f_row97_col3, #T_1603f_row98_col3, #T_1603f_row99_col3, #T_1603f_row100_col3, #T_1603f_row101_col3, #T_1603f_row102_col3, #T_1603f_row103_col3, #T_1603f_row104_col3,
col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.0%, #de9910 38.0%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_1603f_row20_col6, #T_1603f_row67_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.1%, #de9910 38.1%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_1603f_row22_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.4%, #de9910 38.4%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_1603f_row23_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.7%, #de9910 38.7%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_1603f_row24_col6, #T_1603f_row25_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.8%, #de9910 38.8%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_1603f_row27_col6, #T_1603f_row56_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.1%, #de9910 39.1%, #de9910 40.0%, transparent

# %% [markdown]
# **Plot WoE**:

# %%
def plot_woe(woe_series: pd.Series, labels: pd.Series | None = None):
    fig = plt.figure(figsize=(18, 6))

    style_dict = {
                  'xlabel': 'Categories',
                  'title': '{0}'.format(woe_series.name),
                 }
    ax = fig.add_subplot(1,1,1, **style_dict)
    ax.grid()
    
    rotate = False
    if isinstance(woe_series.index.values[0], pd.Interval):
        x =  list(map(str, woe_series.index.values))
        rotate = True
        
    else:
        x = woe_series.index.values
        
    ax.plot(x, woe_series.values, color='red', marker='o', linestyle='--')

    if rotate:
        ax.set_xticks(np.arange(0, len(x)))
        ax.set_xticklabels(x, rotation = 90)
        
    if labels is not None:
        for (i, label), value in zip(enumerate(labels.values), woe_series.values) :
            ax.text(i, value + 0.1, label)
            
    return ax

# %%
plot_woe(woe_summary.loc['grade', :]['woe'], labels=woe_summary.loc['grade', :]['n_obs_rel'].apply(lambda v: 'rel. freq.:{0:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %% [markdown]
# **Coarse classing mechanism**

# %%
from collections.abc import Iterable
import abc

PathLike = TypeVar('PathLike', str, Path, None)

class Component(Iterable, abc.ABC):

    def __init__(self, *args, **kwargs):
        self.children = list()
        self._name: str = ''
        self._is_reference: bool = False
    
    def add_child(self, element) -> 'Component':
        self.children.append(element)

        return self
        
    def remove_child(self, element) -> 'Component':
        self.children.remove(element)

        return self

    def _str_leaves(self, indent: int = 0) -> str:
        reference_mark = '***' if self._is_reference else ''
        initial_str: str = '|\t' * indent + f'|----{self.name}{reference_mark}\n'
        for element in self:
            if isinstance(element, Component):
                initial_str += element._str_leaves(indent + 1)

            else:
                initial_str += '|\t' * (indent + 1) + f'|----{str(element)}\n'

        return initial_str
        
    @abc.abstractmethod
    def transform(self, *args, **kwargs) -> Any: pass

    @abc.abstractproperty
    def name(self) -> str: pass

    def __str__(self) -> str:
        return self._str_leaves(indent=0)

class RefComponent(Component):

    def __init__(self, is_reference: bool = False, *args, **kwargs):
        Component.__init__(self, *args, **kwargs)
        self._is_reference = is_reference
        
class Group(RefComponent):

    def transform(self) -> Callable:
        return self.children.__contains__

    @property
    def name(self):
        return '_'.join(map(str, self.children))

    def extend_group(self, elements) -> Component:
        self.children.extend(elements)

        return self

    def __iter__(self):
        for value in self.children:
            yield value

    def to_dict(self) -> Dict[str, Any]:
        return {
                'name': self.name,
                'type': 'group',
                'children': self.children,
                'is_reference': self._is_reference
        }

class Interval(RefComponent):

    def transform(self) -> Callable:
        return self.children[0].__contains__

    @property
    def name(self):
        return '_'.join(map(str, self.children))

    def __iter__(self):
        yield self.children[0]

    def to_dict(self) -> Dict[str, Any]:
        return {
                'name': self.name,
                'type': 'interval',
                'left': self.children[0].left,
                'right': self.children[0].right,
                'closed': self.children[0].closed,
                'is_reference': self._is_reference
        }

class GroupedColumn(Group):

    def __init__(self, name: str, *args, **kwargs):
        Component.__init__(self, *args, **kwargs)
        self._name = name

    def transform(self, series: pd.Series, keep_reference: bool = True) -> pd.DataFrame:
        df_dict: dict[str, pd.Series] = {}
        for group in self:
            if group._is_reference and not keep_reference:
                pass
                
            else:
                df_dict[self.name + ':' + group.name] = series.apply(group.transform()).apply(int)
            
        return pd.DataFrame(df_dict)

    @property
    def name(self):
        return self._name

    def add_remainder(self, elements: List[str]) -> Component:
        new_elements = set(elements)
        for column in self:
            new_elements-= set(column.children)

        if new_elements:
            self.add_child(Group().extend_group(list(new_elements)))

        return self

    def add_one_category_groups(self, elements: List[str]) -> Component:
        for element in elements:
            self.add_child(Group().add_child(element))

        return self

    def to_dict(self) -> Dict[str, Any]:
        d = dict()
        d['name'] = self.name
        d['children'] = []
        for group in self:
            d['children'].append(group.to_dict())

        return d


class DataFrameTransform(Group):

    def transform(self, df: pd.DataFrame, remove_originals: bool = False, keep_reference: bool = True) -> pd.DataFrame:
        for column in self:
            df = pd.concat([df, column.transform(df[column.name], keep_reference)], axis=1)
            if remove_originals:
                df = df.drop(column.name, axis=1)
            
        return df

    @property
    def name(self):
        return 'DataFrameTransform'

    def to_dict(self) -> List[Dict[str, Any]]:
        l = []
        for group in self:
            l.append(group.to_dict())

        return l

    def to_json(self, path: PathLike = None) -> None | str:
        if path:
            with open(path, 'w') as f:
                json.dump(self.to_dict(), f)

        else:
            return json.dumps(self.to_dict())

    @classmethod
    def from_json(cls, path: PathLike) -> 'DataFrameTransform':
        with open(path, 'r') as f:
            grouped_columns = json.load(f)
        
        c = cls()
        for gcolumn in grouped_columns:
            gc = GroupedColumn(gcolumn['name'])
            c.add_child(gc)
            for group in gcolumn['children']:
                if group['type'] == 'group':
                    gc.add_child(Group(group['is_reference']).extend_group(group['children']))

                elif group['type'] == 'interval':
                    gc.add_child(pd.Interval(left=group['left'], right=group['right'], closed=group['closed']))
                    
        return c

# %% [markdown]
# ### Group Categories
#
# Variables:
# - Home ownership
# - Grade
# - State
# - Verification status
# - Purpose
# - Initial List status

# %%
dft = DataFrameTransform()

# %% [markdown]
# **Grade**

# %%
grade_groups = GroupedColumn('grade')

# %%
plot_woe(woe_summary.loc['grade', :]['woe'], labels=woe_summary.loc['grade', :]['n_obs_rel'].apply(lambda v: 'rel. freq.:{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
grade_groups.add_child(Group(is_reference=True).extend_group(['G', 'F', 'E']))

# %%
grade_groups.add_one_category_groups(['D', 'C', 'B', 'A'])

# %%
print(grade_groups)
# Out:
# |----grade
# |	|----G_F_E***
# |	|	|----G
# |	|	|----F
# |	|	|----E
# |	|----D
# |	|	|----D
# |	|----C
# |	|	|----C
# |	|----B
# |	|	|----B
# |	|----A
# |	|	|----A

# %%
dft.add_child(grade_groups)

# %% [markdown]
# **Home ownership**

# %%
owner_groups = GroupedColumn('home_ownership')

# %%
plot_woe(woe_summary.loc['home_ownership', :]['woe'], labels=woe_summary.loc['home_ownership', :]['n_obs_rel'].apply(lambda v: 'rel. freq.:{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
under_represented_n_risky = Group(is_reference=True).add_child('OTHER').add_child('NONE').add_child('ANY').add_child('RENT')

# %%
owner_groups.add_child(under_represented_n_risky)

# %%
owner_groups.add_one_category_groups(['OWN', 'MORTGAGE'])

# %%
dft.add_child(owner_groups)
print(dft)
# Out:
# |----DataFrameTransform
# |	|----grade
# |	|	|----G_F_E***
# |	|	|	|----G
# |	|	|	|----F
# |	|	|	|----E
# |	|	|----D
# |	|	|	|----D
# |	|	|----C
# |	|	|	|----C
# |	|	|----B
# |	|	|	|----B
# |	|	|----A
# |	|	|	|----A
# |	|----home_ownership
# |	|	|----OTHER_NONE_ANY_RENT***
# |	|	|	|----OTHER
# |	|	|	|----NONE
# |	|	|	|----ANY
# |	|	|	|----RENT
# |	|	|----OWN
# |	|	|	|----OWN
# |	|	|----MORTGAGE
# |	|	|	|----MORTGAGE

# %% [markdown]
# **State**

# %%
states_groups = GroupedColumn('addr_state')

# %%
plot_woe(woe_summary.loc['addr_state', :]['woe'], labels=woe_summary.loc['addr_state', :]['n_obs_rel'].apply(lambda v: 'rel. freq.:{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
style_woe_frame(woe_summary.loc['addr_state', :])
# Out:
# <style type="text/css">
# #T_ae2da_row0_col3, #T_ae2da_row1_col3, #T_ae2da_row2_col3, #T_ae2da_row3_col3, #T_ae2da_row5_col3, #T_ae2da_row6_col3, #T_ae2da_row8_col3, #T_ae2da_row9_col3, #T_ae2da_row10_col3, #T_ae2da_row11_col3, #T_ae2da_row12_col3, #T_ae2da_row13_col3, #T_ae2da_row14_col3, #T_ae2da_row16_col3, #T_ae2da_row17_col3, #T_ae2da_row18_col3, #T_ae2da_row19_col3, #T_ae2da_row20_col3, #T_ae2da_row21_col3, #T_ae2da_row22_col3, #T_ae2da_row23_col3, #T_ae2da_row24_col3, #T_ae2da_row25_col3, #T_ae2da_row26_col3, #T_ae2da_row27_col3, #T_ae2da_row28_col3, #T_ae2da_row29_col3, #T_ae2da_row30_col3, #T_ae2da_row31_col3, #T_ae2da_row32_col3, #T_ae2da_row33_col3, #T_ae2da_row35_col3, #T_ae2da_row36_col3, #T_ae2da_row37_col3, #T_ae2da_row38_col3, #T_ae2da_row39_col3, #T_ae2da_row40_col3, #T_ae2da_row41_col3, #T_ae2da_row42_col3, #T_ae2da_row43_col3, #T_ae2da_row44_col3, #T_ae2da_row45_col3, #T_ae2da_row46_col3, #T_ae2da_row47_col3, #T_ae2da_row48_col3, #T_ae2da_row49_col3 {
#   background-color: #cc5040;
#   border-width: 1px;
#   border-color: #ffffff;
#   border-style: dashed;
# }
# #T_ae2da_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.8%, #de9910 34.8%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_ae2da_
da_level0_row20, #T_ae2da_level0_row21, #T_ae2da_level0_row22, #T_ae2da_level0_row23, #T_ae2da_level0_row24, #T_ae2da_level0_row25, #T_ae2da_level0_row26, #T_ae2da_level0_row27, #T_ae2da_level0_row28, #T_ae2da_level0_row29, #T_ae2da_level0_row30, #T_ae2da_level0_row31, #T_ae2da_level0_row32, #T_ae2da_level0_row33, #T_ae2da_level0_row34, #T_ae2da_level0_row35, #T_ae2da_level0_row36, #T_ae2da_level0_row37, #T_ae2da_level0_row38, #T_ae2da_level0_row39, #T_ae2da_level0_row40, #T_ae2da_level0_row41, #T_ae2da_level0_row42, #T_ae2da_level0_row43, #T_ae2da_level0_row44, #T_ae2da_level0_row45, #T_ae2da_level0_row46, #T_ae2da_level0_row47, #T_ae2da_level0_row48, #T_ae2da_level0_row49 {
#   background-color: #b20f4f;
#   border-width: 2px;
#   border-color: #ffffff;
#   border-style: solid;
#   text-align: center;
# }
# #T_ae2da_level0_col0, #T_ae2da_le

# %%
len(woe_summary.loc['addr_state', :])
# Out:
# 50

# %% [markdown]
# North Dakota is missing in the sample!

# %%
plot_woe(woe_summary.loc['addr_state', :].iloc[2:-1, :]['woe'],
         labels=woe_summary.loc['addr_state', :].iloc[2:-1, :]['n_obs_rel'].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
states_groups.add_child(Group(is_reference=True).extend_group(['NE', 'IA', 'ND', 'NV', 'HI', 'FL', 'AL']))\
             .add_child(Group().extend_group(['ID', 'CO', 'KS', 'VT', 'AK', 'NH', 'WV', 'DC','WY','ME'])) #best and underrepresented

# %%
plot_woe(woe_summary.loc['addr_state', :].iloc[6:-10, :]['woe'],
         labels=woe_summary.loc['addr_state', :].iloc[6:-10, :]['n_obs_rel'].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
states_groups.add_child(Group().extend_group(['NY', 'MO']))\
             .add_child(Group().add_child('CA'))

# %%
states_groups.add_child(Group().extend_group(['NC', 'MD', 'OK', 'VA', 'NM', 'AR', 'LA']))

# %%
states_groups.add_child(Group().extend_group(['NJ', 'RI', 'AZ', 'TN']))

# %%
states_groups.add_child(Group().extend_group(['UT', 'MI', 'KY', 'PA']))

# %%
states_groups.add_child(Group().extend_group(['OH', 'MN', 'IN', 'DE', 'MA']))

# %%
states_groups.add_child(Group().extend_group(['SD', 'GA', 'WA', 'WI', 'OR']))

# %%
states_groups.add_child(Group().add_child('TX'))

# %%
states_groups.add_child(Group().extend_group(['IL', 'MT', 'CT', 'SC', 'MS']))

# %%
dft.add_child(states_groups)

# %%
print(dft)
# Out:
# |----DataFrameTransform
# |	|----grade
# |	|	|----G_F_E***
# |	|	|	|----G
# |	|	|	|----F
# |	|	|	|----E
# |	|	|----D
# |	|	|	|----D
# |	|	|----C
# |	|	|	|----C
# |	|	|----B
# |	|	|	|----B
# |	|	|----A
# |	|	|	|----A
# |	|----home_ownership
# |	|	|----OTHER_NONE_ANY_RENT***
# |	|	|	|----OTHER
# |	|	|	|----NONE
# |	|	|	|----ANY
# |	|	|	|----RENT
# |	|	|----OWN
# |	|	|	|----OWN
# |	|	|----MORTGAGE
# |	|	|	|----MORTGAGE
# |	|----addr_state
# |	|	|----NE_IA_ND_NV_HI_FL_AL***
# |	|	|	|----NE
# |	|	|	|----IA
# |	|	|	|----ND
# |	|	|	|----NV
# |	|	|	|----HI
# |	|	|	|----FL
# |	|	|	|----AL
# |	|	|----ID_CO_KS_VT_AK_NH_WV_DC_WY_ME
# |	|	|	|----ID
# |	|	|	|----CO
# |	|	|	|----KS
# |	|	|	|----VT
# |	|	|	|----AK
# |	|	|	|----NH
# |	|	|	|----WV
# |	|	|	|----DC
# |	|	|	|----WY
# |	|	|	|----ME
# |	|	|----NY_MO
# |	|	|	|----NY
# |	|	|	|----MO
# |	|	|----CA
# |	|	|	|----CA
# |	|	|----NC_MD_OK_VA_NM_AR_LA
# |	|	|	|----NC
# |	|	|	|----MD
# |	|	|	|----OK
# |	|	|	|----VA
# |	|	|	|----NM
# |	|	|	|----AR
# |	|	|	|----LA
# |	|	|----NJ_RI_AZ_TN
# |	|	|	|----NJ
# |	|	|	|----RI
# |	|	|	|----AZ
# |	|	|	|----TN
# |	|	|----UT_MI_KY_PA
# |	|	|	|----UT
# |	|	|	|----MI
# |	|	|	|----KY
# |	|	|	|----PA
# |	|	|----OH_MN_IN_DE_MA
# |	|	|	|----OH
# |	|	|	|----MN
# |	|	|	|----IN
# |	|	|	|----DE
# |	|	|	|----MA
# |	|	|----SD_GA_WA_WI_OR
# |	|	|	|----SD
# |	|	|	|----GA
# |	|	|	|----WA
# |	|	|	|----WI
# |	|	|	|----OR
# |	|	|----TX
# |	|	|	|----TX
# |	|	|----IL_MT_CT_SC_MS
# |	|	|	|----IL
# |	|	|	|----MT
# |	|	|	|----CT
# |	|	|	|----SC
# |	|	|	|----MS

# %% [markdown]
# **Verification status**

# %%
verification_groups = GroupedColumn('verification_status')

# %%
plot_woe(woe_summary.loc['verification_status', :]['woe'], labels=woe_summary.loc['verification_status', :]['n_obs_rel'].apply(lambda v: 'rel. freq.:{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
verification_groups.add_one_category_groups(woe_summary.loc['verification_status', :].index.to_list())

# %%
dft.add_child(verification_groups)

# %% [markdown]
# **Purpose**

# %%
purpose_groups = GroupedColumn('purpose')

# %%
plot_woe(woe_summary.loc['purpose', :]['woe'], labels=woe_summary.loc['purpose', :]['n_obs_rel'].apply(lambda v: 'rel. freq.:{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
purpose_groups.add_child(
        Group().extend_group(['educational', 'small_business', 'wedding', 'renewable_energy', 'moving', 'house', 'other', 'medical', 'vacation'])
    ).add_child(
        Group().add_child('debt_consolidation')
    ).add_child(
        Group().extend_group(['major_purchase', 'car', 'home_improvement'])
    ).add_child(
        Group().add_child('credit_card')
    )

# %%
dft.add_child(purpose_groups)

# %% [markdown]
# **Initial List status**

# %%
initial_list_groups = GroupedColumn('initial_list_status')

# %%
woe_summary.loc['initial_list_status', :].head()
# Out:
# non_default      0       1   n_obs  n_obs_rel   bad_rel  good_rel       woe  \
# f            32820  239953  272773   0.649992  0.715485  0.641955 -0.108443
# w            13051  133832  146883   0.350008  0.284515  0.358045  0.229873
#
# non_default  good_rel_diff  bad_rel_diff  woe_diff  accum_n_obs_rel        iv
# f                      NaN           NaN       NaN         0.649992  0.024876
# w                 0.283909      0.430969  0.338316         1.000000  0.024876

# %%
initial_list_groups.add_one_category_groups(['f', 'w'])

# %%
print(initial_list_groups)
# Out:
# |----initial_list_status
# |	|----f
# |	|	|----f
# |	|----w
# |	|	|----w

# %%
dft.add_child(initial_list_groups)

# %%
encoded_cat_df: pd.DataFrame = dft.transform(cat_df, remove_originals=True, keep_reference=False)

# %%
encoded_cat_df.shape
# Out:
# (419656, 33)

# %%
dft.to_json('../data/curated/categorical_vars_transformation.json')

# %% [markdown]
# #### Continuous Variables

# %%
BINS = 50

# %%
continuous_vars: List[str] = [
    'term_int',
    'non_default',
    'emp_length_int',
    'months_since_issue_d',
    'int_rate',
    'funded_amnt',
    'months_since_earliest_cr_line',
    'installment',
    'delinq_2yrs',
    'inq_last_6mths',
    'open_acc',
    'pub_rec',
    'total_acc',
    'acc_now_delinq',
    'annual_inc',
    'dti',
    'mths_since_last_record'
]

# %%
continuous_df: pd.DataFrame = df_train[continuous_vars].copy()

# %%
continuous_dft = DataFrameTransform()

# %% [markdown]
# **Term int**

# %%
style_woe_frame(
        calculate_woe_iv(continuous_df, continuous_df['term_int'], continuous_df['non_default'], multilevel_index=False, sort_by_woe=False)
)
# Out:
# <style type="text/css">
# #T_28e23_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 58.0%, transparent 58.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_28e23_row0_col11, #T_28e23_row1_col11 {
#   background-color: #e5d544;
#   color: #000000;
# }
# #T_28e23_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_28e23_level0_row0, #T_28e23_level0_row1 {
#   background-color: #b20f4f;
#   border-width: 2px;
#   border-color: #ffffff;
#   border-style: solid;
#   text-align: center;
# }
# #T_28e23_level0_col0, #T_28e23_level0_col1, #T_28e23_level0_col2, #T_28e23_level0_col3, #T_28e23_level0_col4, #T_28e23_level0_col5, #T_28e23_level0_col6, #T_28e23_level0_col7, #T_28e23_level0_col8, #T_28e23_level0_col9, #T_28e23_level0_col10, #T_28e23_level0_col11 {
#   background-color: #b20f4f;
#   border-width: 2px;
#   border-color: #ffffff;
#   border-style: solid;
#   text-align: center;
# }
# </style>
# <table id="T_28e23">
#   <caption>Weight of evidence analysis</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >non_default</th>
#       <th id="T_28e23_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_28e23_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_28e23_level0_col2" class="col_heading level0 col2" >n_obs</th>
#       <th id="T_28e23_level0_col3" class="col_heading level0 col3" >n_obs_rel</th>
#       <th id="T_28e23_level0_col4" class="col_heading level0 col4" >bad_rel</th>
#       <th id="T_28e23_level0_col5" class="col_heading level0 col5" >good_rel</th>
#       <th id="T_28e23_level0_col6" class="col_heading level0 col6" >woe</th>
#       <th id="T_28e23_level0_col7" class="col_heading level0 col7" >good_rel_diff</th>
#       <th id="T_28e23_level0_col8" class="col_heading level0 col8" >bad_rel_diff</th>
#       <th id="T_28e23_level0_col9" class="col_heading level0 col9" >woe_diff</th>
#       <th id="T_28e23_level0_col10" class="col_heading level0 col10" >accum_n_obs_rel</th>
#       <th id="T_28e23_level0_col11" class="col_heading level0 col11" >iv</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >term_int</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28e23_level0_row0" class="row_heading level0 row0" >36</th>
#       <td id="T_28e23_row0_col0" class="data row0 col0" >29,492</td>
#       <td id="T_28e23_row0_col1" class="data row0 col1" >274,678</td>
#       <td id="T_28e23_row0_col2" class="data row0 col2" >304,170</td>
#       <td id="T_28e23_row0_col3" class="data row0 col3" >72.48%</td>
#       <td id="T_28e23_row0_col4" class="data row0 col4" >64.29%</td>
#       <td id="T_28e23_row0_col5" class="data row0 col5" >73.49%</td>
#       <td id="T_28e23_row0_col6" class="data row0 col6" >0.134</td>
#       <td id="T_28e23_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_28e23_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_28e23_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_28e23_row0_col10" class="data row0 col10" >72.48%</td>
#       <td id="T_28e23_row0_col11" class="data row0 col11" >0.040</td>
#     </tr>
#     <tr>
#       <th id="T_28e23_level0_row1" class="row_heading level0 row1" >60</th>
#       <td id="T_28e23_row1_col0" class="data row1 col0" >16,379</td>
#       <td id="T_28e23_row1_col1" class="data row1 col1" >99,107</td>
#       <td id="T_28e23_row1_col2" class="data row1 col2" >115,486</td>
#       <td id="T_28e23_row1_col3" class="data row1 col3" >27.52%</td>
#       <td id="T_28e23_row1_col4" class="data row1 col4" >35.71%</td>
#       <td id="T_28e23_row1_col5" class="data row1 col5" >26.51%</td>
#       <td id="T_28e23_row1_col6" class="data row1 col6" >-0.298</td>
#       <td id="T_28e23_row1_col7" class="data row1 col7" >0.470</td>
#       <td id="T_28e23_row1_col8" class="data row1 col8" >0.286</td>
#       <td id="T_28e23_row1_col9" class="data row1 col9" >0.431</td>
#       <td id="T_28e23_row1_col10" class="data row1 col10" >100.00%</td>
#       <td id="T_28e23_row1_col11" class="data row1 col11" >0.040</td>
#     </tr>
#   </tbody>
# </table>

# %%
continuous_df['term_int'].unique().tolist()
# Out:
# [36, 60]

# %%
term_int_groups: GroupedColumn = GroupedColumn('term_int').add_child(Group().add_child(36))\
                                                          .add_child(Group(is_reference=True).add_child(60))

# %%
continuous_dft.add_child(term_int_groups)

# %%
print(continuous_dft)
# Out:
# |----DataFrameTransform
# |	|----term_int
# |	|	|----36
# |	|	|	|----36
# |	|	|----60***
# |	|	|	|----60

# %% [markdown]
# **Emp length int**

# %%
emp_length_groups = GroupedColumn('emp_length_int')

# %%
continuous_df['emp_length_int'].unique()
# Out:
# array([ 0,  2, 10,  9,  1,  3,  6,  8,  7,  5,  4], dtype=int8)

# %%
emp_length_woe = calculate_woe_iv(continuous_df, continuous_df['emp_length_int'], continuous_df['non_default'], multilevel_index=False, sort_by_woe=False)

# %%
style_woe_frame(emp_length_woe)
# Out:
# <style type="text/css">
# #T_2f819_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_2f819_row0_col11, #T_2f819_row1_col11, #T_2f819_row2_col11, #T_2f819_row3_col11, #T_2f819_row4_col11, #T_2f819_row5_col11, #T_2f819_row6_col11, #T_2f819_row7_col11, #T_2f819_row8_col11, #T_2f819_row9_col11, #T_2f819_row10_col11 {
#   background-color: #f0ad24;
#   color: #000000;
# }
# #T_2f819_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.3%, #de9910 31.3%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_2f819_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.9%, #de9910 39.9%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_2f819_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 42.1%, transparent 42.1%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_2f819_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.2%, #de9910 38.2%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_2f819_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.2%, #de9910 22.2%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_2f819_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 17.5%, #de9910 17.5%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_2f819_row7_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.8%, #de9910 33.8%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_2f819_row8_col3, #T_2f819_row9_col3 {
#   background-color: #cc5040;
#   border-width: 1px;
#   border-color: #ffffff;
#   border-style: dashed;
# }
# #T_2f819_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.5%, #de9910 38.5%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_2f819_row9_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.1%, #de9910 35.1%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_2f819
>0.007</td>
#     </tr>
#     <tr>
#       <th id="T_2f819_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2f819_row2_col0" class="data row2 col0" >4,071</td>
#       <td id="T_2f819_row2_col1" class="data row2 col1" >33,166</td>
#       <td id="T_2f819_row2_col2" class="data row2 col2" >37,237</td>
#       <td id="T_2f819_row2_col3" class="data row2 col3" >8.87%</td>
#       <td id="T_2f819_row2_col4" class="data row2 col4" >8.87%</td>
#       <td id="T_2f819_row2_col5" class="data row2 col5" >8.87%</td>
#       <td id="T_2f819_row2_col6" class="data row2 col6" >-0.000</td>
#       <td id="T_2f819_row2_col7" class="data row2 col7" >0.025</td>
#       <td id="T_2f819_row2_col8" class="data row2 col8" >0.023</td>
#       <td id="T_2f819_row2_col9" class="data row2 col9" >0.031</td>
#       <td id="T_2f819_row2_col10" class="data row2 col10" >27.51%</td>
#       <td id="T_2f819_row2_col11" class="data row2 col11" >0.007</td>
#     </tr>
#     <tr>
#       <th id="T_2f819_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2f819_row3_col0" class="data row3 col0" >3,593</td>
#       <td id="T_2f819_row3_col1" class="data row3 col1" >29,500</td>

# %%
plot_woe(emp_length_woe['woe'], labels=emp_length_woe['n_obs_rel'].apply(lambda v: 'Rel. Freq: {:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
emp_length_groups.add_child(
        Group(is_reference=True).add_child(0)
    ).add_child(
        Group().add_child(1)
    ).add_child(
        Group().extend_group([2, 3, 4])
    ).add_child(
        Group().extend_group([5, 6])
    ).add_child(
        Group().extend_group([7, 8, 9])
    ).add_child(
        Group().add_child(10)
    )

# %%
print(emp_length_groups)
# Out:
# |----emp_length_int
# |	|----0***
# |	|	|----0
# |	|----1
# |	|	|----1
# |	|----2_3_4
# |	|	|----2
# |	|	|----3
# |	|	|----4
# |	|----5_6
# |	|	|----5
# |	|	|----6
# |	|----7_8_9
# |	|	|----7
# |	|	|----8
# |	|	|----9
# |	|----10
# |	|	|----10

# %%
continuous_dft.add_child(emp_length_groups)

# %% [markdown]
# **Months since issue date**

# %%
m_issue_groups = GroupedColumn('months_since_issue_d')

# %%
msid_woe = calculate_woe_iv(
                continuous_df,
                pd.cut(continuous_df['months_since_issue_d'], bins=BINS, retbins=False),
                continuous_df['non_default'], multilevel_index=False, sort_by_woe=False
)

# %%
plot_woe(msid_woe['woe'], labels=msid_woe['n_obs_rel'].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
m_issue_groups.add_child(
        Interval(is_reference=True).add_child(pd.Interval(left=-np.inf, right=38, closed='right'))
    )

# %%
m_issue_groups.add_child(
        Interval().add_child(pd.Interval(left=38, right=40, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=40, right=42, closed='right'))
    )

# %%
plot_woe(msid_woe['woe'].iloc[3:], labels=msid_woe['n_obs_rel'].iloc[3:].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
m_issue_groups.add_child(
        Interval(is_reference=True).add_child(pd.Interval(left=42, right=44, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=44, right=46, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=46, right=49, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=49, right=51, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=51, right=53, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=53, right=58, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=58, right=84, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=84, right=np.inf, closed='right'))
    )

# %%
continuous_dft.add_child(m_issue_groups)

# %% [markdown]
# **Interest rate**

# %%
int_rate_groups = GroupedColumn('int_rate')

# %%
int_rate_woe = calculate_woe_iv(
                continuous_df,
                pd.cut(continuous_df['int_rate'], bins=BINS, retbins=False),
                continuous_df['non_default'], multilevel_index=False, sort_by_woe=False
)

# %%
row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 80.0%, transparent 80.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 72.8%, transparent 72.8%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 70.5%, transparent 70.5%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 77.9%, transparent 77.9%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 66.2%, transparent 66.2%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 58.9%, transparent 58.9%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row7_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 67.6%, transparent 67.6%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 54.4%, transparent 54.4%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row9_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 67.7%, transparent 67.7%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row10_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 51.5%, transparent 51.5%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row11_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 52.6%, transparent 52.6%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row12_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 45.9%, transparent 45.9%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row13_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 51.3%, transparent 51.3%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row14_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 47.3%, transparent 47.3%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row15_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 52.0%, transparent 52.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row16_col6, #T_7dcd5_row20_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 41.0%, transparent 41.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row17_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 48.4%, transparent 48.4%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row18_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 43.2%, transparent 43.2%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row19_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 43.8%, transparent 43.8%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row21_col6, #T_7dcd5_row24_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.2%, #de9910 39.2%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row22_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.6%, #de9910 34.6%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row23_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.0%, #de9910 38.0%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row25_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.9%, #de9910 29.9%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row26_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.2%, #de9910 33.2%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row27_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.8%, #de9910 30.8%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row28_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.3%, #de9910 32.3%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row29_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 30.0%, #de9910 30.0%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row30_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 27.7%, #de9910 27.7%, #de9910 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_7dcd5_row31_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.3%, #de9910 29.3%, #de9910 40.0%, trans

# %%
plot_woe(int_rate_woe['woe'], labels=int_rate_woe['n_obs_rel'].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
int_rate_groups.add_child(
        Interval(is_reference=True).add_child(pd.Interval(left=-np.inf, right=10.374, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=10.374, right=14.089, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=14.089, right=15.74, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=15.74, right=20.281, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=20.281, right=np.inf, closed='right'))
    )

# %%
continuous_dft.add_child(int_rate_groups)

# %% [markdown]
# **Funded amount**

# %%
funded_amnt_groups = GroupedColumn('funded_amnt')

# %%
funded_amnt_woe = calculate_woe_iv(
                continuous_df,
                pd.cut(continuous_df['funded_amnt'], bins=BINS, retbins=False),
                continuous_df['non_default'], multilevel_index=False, sort_by_woe=False
)

# %%
plot_woe(funded_amnt_woe['woe'], labels=funded_amnt_woe['n_obs_rel'].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %% [markdown]
# **Volatile behaviour around a flat trend**: do not use the variable in the model!

# %%
continuous_df = continuous_df.drop('funded_amnt', axis=1)

# %% [markdown]
# **months_since_earliest_cr_line**

# %%
earliest_cr_groups = GroupedColumn('months_since_earliest_cr_line')

# %%
earliest_cr_woe = calculate_woe_iv(
                continuous_df,
                pd.cut(continuous_df['months_since_earliest_cr_line'], bins=BINS, retbins=False),
                continuous_df['non_default'], multilevel_index=False, sort_by_woe=False
)

# %%
style_woe_frame(earliest_cr_woe)
# Out:
# <style type="text/css">
# #T_8eb62_row0_col3, #T_8eb62_row1_col3, #T_8eb62_row2_col3, #T_8eb62_row3_col3, #T_8eb62_row4_col3, #T_8eb62_row14_col3, #T_8eb62_row15_col3, #T_8eb62_row16_col3, #T_8eb62_row17_col3, #T_8eb62_row18_col3, #T_8eb62_row19_col3, #T_8eb62_row20_col3, #T_8eb62_row21_col3, #T_8eb62_row22_col3, #T_8eb62_row23_col3, #T_8eb62_row24_col3, #T_8eb62_row25_col3, #T_8eb62_row26_col3, #T_8eb62_row27_col3, #T_8eb62_row28_col3, #T_8eb62_row29_col3, #T_8eb62_row30_col3, #T_8eb62_row31_col3, #T_8eb62_row32_col3, #T_8eb62_row33_col3, #T_8eb62_row34_col3, #T_8eb62_row35_col3, #T_8eb62_row36_col3, #T_8eb62_row37_col3, #T_8eb62_row38_col3, #T_8eb62_row39_col3, #T_8eb62_row40_col3, #T_8eb62_row41_col3, #T_8eb62_row42_col3, #T_8eb62_row43_col3, #T_8eb62_row44_col3, #T_8eb62_row45_col3, #T_8eb62_row46_col3 {
#   background-color: #cc5040;
#   border-width: 1px;
#   border-color: #ffffff;
#   border-style: dashed;
# }
# #T_8eb62_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39
col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 74.6%, transparent 74.6%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_8eb62_row42_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 78.8%, transparent 78.8%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_8eb62_row45_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.0%, #7acd53 40.0%, #7acd53 76.2%, transparent 76.2%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_8eb62_level0_row0, #T_8eb62_level0_row1, #T_8eb62_level0_row2, #T_8eb62_level0_row3, #T_8eb62_level0_row4, #T_8eb62_level0_row5, #T_8eb62_level0_row6, #T_8eb62_level0_row7, #T_8eb62_level0_row8, #T_8eb62_level0_row9, #T_8eb62_level0_row10, #T_8eb62_level0_row11, #T_8eb62_level0_row12, #T_8eb62_level0_row13, #T_8eb62_level0_row14, #T_8eb62_level0_row15, #T_8eb62_level0_row16, #T_8eb62_level0_row17, #T_8eb62_level0_row18, #T_8eb62_level0_row19, #T_8eb62_level0_row20, #T_8eb62_level0_row21, #T_8eb62_level0_row22, #T_8eb62_level0_row23, #T_8eb62_level0_row24, #T_8eb62_level0_row25, #T_8eb62_level0_row26, #T_8eb62_level0_row27, #T_8eb62_level0_row28, #T_8eb62_level0_row29, #T_8eb62_level0_row30, #T_8eb62_level0_row31, #T_8eb62_level0_row32, #T_8eb62_level0_row33, #T_8eb62_level0_row34, #T_8eb62_level0_row35, #T_8eb62_level0_row36, #T_8eb62_level0_row37, #T_8eb62_level0_row38, #T_8eb62_level0_row39, #T_8eb62_level0_row40, #T_8eb62_level0_row41, #T_8eb62_level0_row42, #T_8eb62_level0_row43, #T_8eb62_level0_row44, #T_8eb62_level0_row45, #T_8eb62_level0_row46 {

# %%
plot_woe(earliest_cr_woe['woe'][:-10], labels=earliest_cr_woe['n_obs_rel'][:-10].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
earliest_cr_groups.add_child(
        Interval().add_child(pd.Interval(left=-np.inf, right=144, closed='right'))
    ).add_child(
        Interval(is_reference=True).add_child(pd.Interval(left=414, right=np.inf, closed='right'))
    )

# %%
plot_woe(earliest_cr_woe['woe'][5:20], labels=earliest_cr_woe['n_obs_rel'][5:20].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
earliest_cr_groups.add_child(
        Interval().add_child(pd.Interval(left=360, right=414, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=270, right=360, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=270, right=360, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=144, right=162, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=162, right=180, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=180, right=216, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=216, right=252, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=252, right=270, closed='right'))
    )

# %%
continuous_dft.add_child(earliest_cr_groups)

# %% [markdown]
# **installment**

# %%
installment_groups = GroupedColumn('installment')

# %%
installment_woe = calculate_woe_iv(
                    continuous_df,
                    pd.cut(continuous_df['installment'], bins=BINS, retbins=False),
                    continuous_df['non_default'], multilevel_index=False, sort_by_woe=False
)

# %%
plot_woe(installment_woe['woe'], labels=installment_woe['n_obs_rel'].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %% [markdown]
# **Volatile**: do not use!

# %% [markdown]
# **delinq_2yrs**

# %%
delinq_2yrs_groups = GroupedColumn('delinq_2yrs')

# %%
delinq_2yrs_woe = calculate_woe_iv(
                    continuous_df,
                    pd.cut(continuous_df['delinq_2yrs'], bins=BINS, retbins=False),
                    continuous_df['non_default'], multilevel_index=False, sort_by_woe=False
)

# %%
# (23.78, 24.36]  14.713399       0.000002      0.000000   0.693147
# (28.42, 29.0]   14.713399       0.000000      0.000000   0.000000
#
# non_default     accum_n_obs_rel      iv
# delinq_2yrs
# (-0.029, 0.58]         0.821350  0.0009
# (0.58, 1.16]           0.941928  0.0009
# (1.74, 2.32]           0.976907  0.0009
# (2.9, 3.48]            0.989097  0.0009
# (3.48, 4.06]           0.994197  0.0009
# (4.64, 5.22]           0.996847  0.0009
# (5.8, 6.38]            0.998196  0.0009
# (6.96, 7.54]           0.998938  0.0009
# (7.54, 8.12]           0.999318  0.0009
# (8.7, 9.28]            0.999556  0.0009
# (9.86, 10.44]          0.999695  0.0009
# (10.44, 11.02]         0.999783  0.0009
# (11.6, 12.18]          0.999865  0.0009
# (12.76, 13.34]         0.999919  0.0009
# (13.92, 14.5]          0.999936  0.0009
# (14.5, 15.08]          0.999951  0.0009
# (15.66, 16.24]         0.999961  0.0009
# (16.82, 17.4]          0.999968  0.0009
# (17.98, 18.56]         0.999981  0.0009
# (18.56, 19.14]         0.999987  0.0009
# (20.88, 21.46]         0.999991  0.0009
# (21.46, 22.04]         0.999996  0.0009
# (23.78, 24.36]         0.999998  0.0009
# (28.42, 29.0]          1.000000  0.0009

# %%
plot_woe(delinq_2yrs_woe['woe'], labels=delinq_2yrs_woe['n_obs_rel'].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
delinq_2yrs_groups.add_child(
        Interval().add_child(pd.Interval(left=-np.inf, right=.58, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=.58, right=1.16, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=1.16, right=np.inf, closed='right'))
    )

# %%
continuous_dft.add_child(delinq_2yrs_groups)

# %% [markdown]
# **inq_last_6mths**

# %%
inq_6m_groups = GroupedColumn('inq_last_6mths')

# %%
inq_6_groups_woe = calculate_woe_iv(
                    continuous_df,
                    pd.cut(continuous_df['inq_last_6mths'], bins=BINS, retbins=False),
                    continuous_df['non_default'], multilevel_index=False, sort_by_woe=False
)

# %%
inq_6_groups_woe
# Out:
# non_default         0       1   n_obs  n_obs_rel       bad_rel      good_rel  \
# inq_last_6mths
# (-0.033, 0.66]  22043  219484  241527   0.517981  4.324871e-01  5.284734e-01
# (0.66, 1.32]    15040  115108  130148   0.279117  2.950871e-01  2.771570e-01
# (1.98, 2.64]     7887   49938   57825   0.124012  1.547442e-01  1.202407e-01
# (2.64, 3.3]      3995   21131   25126   0.053885  7.838251e-02  5.087921e-02
# (3.96, 4.62]     1108    6133    7241   0.015529  2.173913e-02  1.476703e-02
# (4.62, 5.28]      475    2293    2768   0.005936  9.319573e-03  5.521084e-03
# (5.94, 6.6]       257     931    1188   0.002548  5.042380e-03  2.241661e-03
# (6.6, 7.26]        68     127     195   0.000418  1.334170e-03  3.057905e-04
# (7.92, 8.58]       46      76     122   0.000262  9.025271e-04  1.829928e-04
# (8.58, 9.24]       18      32      50   0.000107  3.531628e-04  7.704958e-05
# (9.9, 10.56]        3      21      24   0.000051  5.886046e-05  5.056379e-05
# (10.56, 11.22]      3      12      15   0.000032  5.886046e-05  2.889359e-05
# (11.88, 12.54]      6       9      15   0.000032  1.177209e-04  2.167019e-05
# (12.54, 13.2]       2       4       6   0.000013  3.924031e-05  9.631197e-06
# (13.86, 14.52]      5       1       6   0.000013  9.810077e-05  2.407799e-06
#
# non_default     accum_n_obs_rel       iv
# inq_last_6mths
# (-0.033, 0.66]         0.517981  0.05374
# (0.66, 1.32]           0.797098  0.05374
# (1.98, 2.64]           0.921110  0.05374
# (2.64, 3.3]            0.974996  0.05374
# (3.96, 4.62]           0.990525  0.05374
# (4.62, 5.28]           0.996461  0.05374
# (5.94, 6.6]            0.999009  0.05374
# (6.6, 7.26]            0.999427  0.05374
# (7.92, 8.58]           0.999689  0.05374
# (8.58, 9.24]           0.999796  0.05374
# (9.9, 10.56]           0.999848  0.05374
# (10.56, 11.22]         0.999880  0.05374
# (11.88, 12.54]         0.999912  0.05374
# (12.54, 13.2]          0.999925  0.05374
# (13.86, 14.52]         0.999938  0.05374
# (14.52, 15.18]         0.999957  0.05374
# (15.84, 16.5]          0.999964  0.05374
# (16.5, 17.16]          0.999968  0.05374
# (17.82, 18.48]         0.999976  0.05374
# (18.48, 19.14]         0.999981  0.05374
# (19.8, 20.46]          0.999983  0.05374
# (23.76, 24.42]         0.999987  0.05374
# (24.42, 25.08]         0.999989  0.05374
# (26.4, 27.06]          0.999991  0.05374
# (27.72, 28.38]         0.999994  0.05374
# (30.36, 31.02]         0.999996  0.05374
# (31.68, 32.34]         0.999998  0.05374
# (32.34, 33.0]          1.000000  0.05374

# %%
plot_woe(inq_6_groups_woe['woe'], labels=inq_6_groups_woe['n_obs_rel'].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
inq_6m_groups.add_child(
        Interval().add_child(pd.Interval(left=-np.inf, right=.66, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=.66, right=1.32, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=1.32, right=2.64, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=2.64, right=np.inf, closed='right'))
    )

# %%
continuous_dft.add_child(inq_6m_groups)

# %% [markdown]
# **open_acc**

# %%
open_acc_groups = GroupedColumn('open_acc')

# %%
open_acc_woe = calculate_woe_iv(
                    continuous_df,
                    pd.cut(continuous_df['open_acc'], bins=BINS, retbins=False),
                    continuous_df['non_default'], multilevel_index=False, sort_by_woe=False
)

# %%
open_acc_woe
# Out:
# non_default        0      1  n_obs  n_obs_rel       bad_rel      good_rel  \
# open_acc
# (-0.084, 1.68]    25    153    178   0.000382  4.905038e-04  3.683933e-04
# (1.68, 3.36]     997   6293   7290   0.015634  1.956129e-02  1.515228e-02
# (3.36, 5.04]    3706  30426  34132   0.073200  7.271229e-02  7.325970e-02
# (5.04, 6.72]    3329  27508  30837   0.066133  6.531549e-02  6.623374e-02
# (6.72, 8.4]     8658  70837  79495   0.170486  1.698713e-01  1.705613e-01
# (8.4, 10.08]    9602  76929  86531   0.185575  1.883927e-01  1.852296e-01
# (10.08, 11.76]  4396  34716  39112   0.083880  8.625020e-02  8.358916e-02
# (11.76, 13.44]  6975  57416  64391   0.138094  1.368506e-01  1.382462e-01
# (13.44, 15.12]  4893  40071  44964   0.096430  9.600141e-02  9.648293e-02
# (15.12, 16.8]   1769  15040  16809   0.036049  3.470805e-02  3.621330e-02
# (16.8, 18.48]   2584  21673  24257   0.052022  5.069848e-02  5.218424e-02
# (18.48, 20.16]  1627  13688  15315   0.032845  3.192199e-02  3.295796e-02
# (20.16, 21.84]   561   4718   5279   0.011321  1.100691e-02  1.136000e-02
# (21.84, 23.52]   751   6504   7255   0.015559  1.473474e-02  1.566033e-02
# (23.52, 25.2]    483   3902   4385   0.009404  9.476534e-03  9.395233e-03
woe['n_obs_rel'].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
open_acc_groups.add_child(
        Interval().add_child(pd.Interval(left=48, right=np.inf, closed='right'))
    )

# %%
plot_woe(open_acc_woe['woe'][:28], labels=open_acc_woe['n_obs_rel'][:28].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
open_acc_groups.add_child(
        Interval().add_child(pd.Interval(left=-np.inf, right=5, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=5, right=8, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=8, right=12, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=12, right=13, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=13, right=14, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=14, right=19, closed='right'))
    )

# %%
continuous_dft.add_child(open_acc_groups)

# %% [markdown]
# **pub_rec**

# %%
pub_rec_groups = GroupedColumn('pub_rec')

# %%
pub_rec_woe = calculate_woe_iv(
                    continuous_df,
                    continuous_df['pub_rec'],
                    continuous_df['non_default'], multilevel_index=False, sort_by_woe=False
)

# %%
pub_rec_woe
# Out:
# non_default      0       1   n_obs  n_obs_rel       bad_rel  good_rel  \
# pub_rec
# 0.0          44627  360295  404922   0.868400  8.755886e-01  0.867518
# 1.0           5572   47479   53051   0.113774  1.093235e-01  0.114320
# 2.0            543    5081    5624   0.012061  1.065374e-02  0.012234
# 3.0            135    1476    1611   0.003455  2.648721e-03  0.003554
# 4.0             47     473     520   0.001115  9.221472e-04  0.001139
# 5.0             25     251     276   0.000592  4.905038e-04  0.000604
# 6.0             10     126     136   0.000292  1.962015e-04  0.000303
# 7.0              5      57      62   0.000133  9.810077e-05  0.000137
# 8.0              1      28      29   0.000062  1.962015e-05  0.000067
# 9.0              3      13      16   0.000034  5.886046e-05  0.000031
# 10.0             0      13      13   0.000028  9.810077e-13  0.000031
# 11.0             0       8       8   0.000017  9.810077e-13  0.000019
# 12.0             0       2       2   0.000004  9.810077e-13  0.000005
# 13.0             0       2       2   0.000004  9.810077e-13  0.000005
# 14.0             0       1       1   0.000002  9.810077e-13  0.000002
# 15.0             0       1       1   0.000002  9.810077e-13  0.000002
# 16.0             0       1       1   0.000002  9.810077e-13  0.000002
# 17.0             0       1       1   0.000002  9.810077e-13  0.000002
# 18.0             0       2       2   0.000004  9.810077e-13  0.000005
# 19.0             0       1       1   0.000002  9.810077e-13  0.000002
# 21.0             0       1       1   0.000002  9.810077e-13  0.000002
# 34.0             0       1       1   0.000002  9.810077e-13  0.000002
# 40.0             0       1       1   0.000002  9.810077e-13  0.000002
# 49.0             0       1       1   0.000002  9.810077e-13  0.000002
# 54.0             0       1       1   0.000002  9.810077e-13  0.000002
# 63.0             0       1       1   0.000002  9.810077e-13  0.000002
#
# non_default        woe  good_rel_diff  bad_rel_diff   woe_diff  \
# pub_rec
# 0.0          -0.009260            NaN           NaN        NaN
# 1.0           0.044689       0.753198      0.766265   0.053949
# 2.0           0.138310       0.102086      0.098670   0.093621
# 3.0           0.293972       0.008680      0.008005   0.155662
# 4.0           0.211104       0.002415      0.001727   0.082868
# 5.0           0.208733       0.000535      0.000432   0.002371
# 6.0           0.435853       0.000301      0.000294   0.227120
# 7.0           0.335769       0.000166      0.000098   0.100083
# 8.0           1.234360       0.000070      0.000078   0.898591
# 9.0          -0.631507       0.000036      0.000039   1.865867
# 10.0         17.278348       0.000000      0.000059  17.909855
# 11.0         16.792840       0.000012      0.000000   0.485508
# 89.0              0.000002      0.000000   0.117783         0.999869  0.013727
# 90.0              0.000002      0.000000   0.117783         0.999888  0.013727
# 91.0              0.000000      0.000020  16.811243         0.999906  0.013727
# 92.0              0.000012      0.000039  18.485219         0.999916  0.013727
# 93.0              0.000007      0.000039  18.197537         0.999929  0.013727
# 94.0              0.000010      0.000020  17.909855         0.999936  0.013727
# 95.0              0.000007      0.000020  17.727534         0.999946  0.013727
# 96.0              0.000010      0.000000   1.609438         0.999949  0.013727
# 97.0              0.000002      0.000000   0.693147         0.999953  0.013727
# 98.0              0.000002      0.000020  17.504390         0.999957  0.013727
# 99.0              0.000005      0.000020  17.909855         0.999964  0.013727
# 100.0             0.000005      0.000000   1.098612         0.999966  0.013727
# 101.0             0.000000      0.000000   0.000000         0.999968  0.013727
# 102.0             0.000002      0.000000   0.693147         0.999972  0.013727
# 105.0             0.000005      0.000000   0.693147         0.999981  0.013727
# 106.0             0.000007      0.000000   1.386294         0.999983  0.013727
# 116.0             0.000000      0.000000   0.000000         0.999985  0.013727
# 117.0             0.000000      0.000000   0.000000         0.999987  0.013727
# 118.0             0.000000      0.000000   0.000000         0.999989  0.013727
# 119.0             0.000000      0.000000   0.000000         0.999991  0.013727
# 121.0             0.000000      0.000000   0.000000         0.999994  0.013727
# 124.0             0.000000      0.000000   0.000000         0.999996  0.013727
# 150.0             0.000000      0.000000   0.000000         0.999998  0.013727
# 156.0             0.000000      0.000000   0.000000         1.000000  0.013727

# %%
plot_woe(total_acc_woe['woe'], labels=total_acc_woe['n_obs_rel'].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
total_acc_groups.add_child(
        Interval().add_child(pd.Interval(left=-np.inf, right=25, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=25, right=45, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=45, right=np.inf, closed='right'))
    )

# %%
continuous_dft.add_child(total_acc_groups)

# %% [markdown]
# **acc_now_delinq**

# %%
acc_now_groups = GroupedColumn('acc_now_delinq')

# %%
acc_now_woe = calculate_woe_iv(
                    continuous_df,
                    continuous_df['acc_now_delinq'],
                    continuous_df['non_default'], multilevel_index=False, sort_by_woe=False
)

# %%
plot_woe(acc_now_woe['woe'], labels=acc_now_woe['n_obs_rel'].apply(lambda v: '{:.2%}'.format(v)))
# Out:
# <Axes: title={'center': 'woe'}, xlabel='Categories'>

# %%
acc_now_groups.add_child(
        Interval().add_child(pd.Interval(left=-np.inf, right=0, closed='right'))
    ).add_child(
        Interval().add_child(pd.Interval(left=0, right=np.inf, closed='right'))
    )

# %%
continuous_dft.add_child(acc_now_groups)

# %% [markdown]
# **Annual inc**

# %%
annual_inc_groups = GroupedColumn('annual_inc')

# %%
annual_inc_woe = calculate_woe_iv(
                    continuous_df,
                    pd.cut(continuous_df['annual_inc'], bins=100, retbins=False),
                    continuous_df['non_default'], multilevel_index=False, sort_by_woe=False
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/CreditRisk/env/lib/python3.12/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'annual_inc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[149], line 3
#       1 annual_inc_woe = calculate_woe_iv(
#       2                     continuous_df,
# ----> 3                     pd.cut(continuous_df['annual_inc'], bins=100, retbins=False),
#       4                     continuous_df['non_default'], multilevel_index=False, sort_by_woe=False
#       5 )
#
# File ~/Documents/CreditRisk/env/lib/python3.12/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/Documents/CreditRisk/env/lib/python3.12/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'annual_inc'

# %% [markdown]
# - dti (debt to income ratio) -> similar to annual_inc
# - mths_since_last_record -> similar to mths_since_last_delinq
